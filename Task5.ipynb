# %% [markdown]
# # Task5

# %% [markdown]
# SALES PREDICTION

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\Vaishnavi\\OneDrive\\Documents\\DATASETS\\Advertising.csv")

# %%
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df = df.drop('Unnamed: 0',axis=1)

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
# x = df.iloc[:,0:4]
x = df[['TV','Radio','Newspaper']]

# %%
x
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y = df.iloc[:,[3]]

# %%
y
# Out:
#      Sales
# 0     22.1
# 1     10.4
# 2      9.3
# 3     18.5
# 4     12.9
# ..     ...
# 195    7.6
# 196    9.7
# 197   12.8
# 198   25.5
# 199   13.4
#
# [200 rows x 1 columns]

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.3,random_state =1)

# %%
x_train
# Out:
#         TV  Radio  Newspaper
# 116  139.2   14.3       25.6
# 67   139.3   14.5       10.2
# 78     5.4   29.9        9.4
# 42   293.6   27.7        1.8
# 17   281.4   39.6       55.8
# ..     ...    ...        ...
# 133  219.8   33.5       45.1
# 137  273.7   28.9       59.7
# 72    26.8   33.0       19.3
# 140   73.4   17.0       12.9
# 37    74.7   49.4       45.7
#
# [140 rows x 3 columns]

# %%
x_test
# Out:
#         TV  Radio  Newspaper
# 58   210.8   49.6       37.7
# 40   202.5   22.3       31.6
# 34    95.7    1.4        7.4
# 102  280.2   10.1       21.4
# 184  253.8   21.3       30.0
# 198  283.6   42.0       66.2
# 95   163.3   31.6       52.9
# 4    180.8   10.8       58.4
# 29    70.6   16.0       40.8
# 168  215.4   23.6       57.6
# 171  164.5   20.9       47.4
# 18    69.2   20.5       18.3
# 11   214.7   24.0        4.0
# 89   109.8   47.8       51.4
# 110  225.8    8.2       56.5
# 118  125.7   36.9       79.2
# 159  131.7   18.4       34.6
# 35   290.7    4.1        8.5
# 136   25.6   39.0        9.3
# 59   210.7   29.5        9.3
# 51   100.4    9.6        3.6
# 16    67.8   36.6      114.0
# 44    25.1   25.7       43.3
# 94   107.4   14.0       10.9
# 31   112.9   17.4       38.6
# 162  188.4   18.1       25.6
# 38    43.1   26.7       35.1
# 28   248.8   27.1       22.9
# 193  166.8   42.0        3.6
# 27   240.1   16.7       22.9
# 47   239.9   41.5       18.5
# ...

# %%
x_test.shape
# Out:
# (60, 3)

# %%
y_train
# Out:
#      Sales
# 116   12.2
# 67    13.4
# 78     5.3
# 42    20.7
# 17    24.4
# ..     ...
# 133   19.6
# 137   20.8
# 72     8.8
# 140   10.9
# 37    14.7
#
# [140 rows x 1 columns]

# %%
y_test
# Out:
#      Sales
# 58    23.8
# 40    16.6
# 34     9.5
# 102   14.8
# 184   17.6
# 198   25.5
# 95    16.9
# 4     12.9
# 29    10.5
# 168   17.1
# 171   14.5
# 18    11.3
# 11    17.4
# 89    16.7
# 110   13.4
# 118   15.9
# 159   12.9
# 35    12.8
# 136    9.5
# 59    18.4
# 51    10.7
# 16    12.5
# 44     8.5
# 94    11.5
# 31    11.9
# 162   14.9
# 38    10.1
# 28    18.9
# 193   19.6
# 27    15.9
# 47    23.2
# 165   11.9
# 194   17.3
# 177   11.7
# 176   20.2
# 97    15.5
# 174   11.5
# 73    11.0
# 69    22.3
# 172    7.6
# 108    5.3
# 107    8.7
# 189    6.7
# 14    19.0
# 56     5.5
# 19    14.6
# 114   14.6
# 39    21.5
# 185   22.6
# 124   19.7
# 98    25.4
# 123   15.2
# 119    6.6
# 53    21.2
# 33    17.4
# 179   12.6
# 181   12.2
# 106    7.2
# 199   13.4
# 138    9.6

# %%
y_test.shape
# Out:
# (60, 1)

# %%
model = LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict = model.predict(x_test)

# %%
y_predict
# Out:
# array([[21.66318307],
#        [16.44137936],
#        [ 7.69144625],
#        [17.9163172 ],
#        [18.67047113],
#        [23.79199311],
#        [16.2825425 ],
#        [13.44138683],
#        [ 9.15294033],
#        [17.32475313],
#        [14.43922876],
#        [ 9.84019547],
#        [17.26329945],
#        [16.62853147],
#        [15.09158705],
#        [15.50173894],
#        [12.43404074],
#        [17.32591521],
#        [11.04327486],
#        [18.05652777],
#        [ 9.35309526],
#        [12.79465958],
#        [ 8.73413846],
#        [10.47225333],
#        [11.38216042],
#        [15.02658554],
#        [ 9.7406823 ],
#        [19.44676903],
#        [18.19211174],
#        [17.20178728],
#        [21.56359539],
#        [14.70484262],
#        [16.2635213 ],
#        [12.37098906],
#        [19.97059316],
#        [15.36768988],
#        [14.00399515],
#        [10.0772945 ],
#        [20.91891557],
#        [ 7.43833283],
#        [ 3.67031166],
# ...

# %%
from sklearn.metrics import r2_score

# %%
score = r2_score(y_test,y_predict)

# %%
score
# Out:
# 0.9224605706201435

# %%
plt.title('Predicted car price',fontsize=15)

plt.xlabel('Actual',fontsize=15)
plt.ylabel('Predicted',fontsize=15)

plt.scatter(y_test,y_predict,color='c')
plt.show()

# %%
plt.title('Predicted car price',fontsize=15)

plt.xlabel('Actual',fontsize=15)
plt.ylabel('Predicted',fontsize=15)

sns.regplot(x=y_test,y=y_predict,color='blue')
plt.show()

# %%
sns.heatmap(df[['TV','Radio','Newspaper']].corr(), cmap='RdBu', annot=True)
# Out:
# <AxesSubplot:>
